# %%
## load initial packages
import pandas as pd
import numpy as np
import striprtf
import re
import os
import geopandas as gpd
import matplotlib.pyplot as plt

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
## load datasets
alabama_hl = pd.read_excel("../data/HLS_data/al_hl_scores.xlsx")
alabama_hl
# Out:
#       Census block group ID  Health literacy estimate
# 0               10010201001                    248.91
# 1               10010201002                    248.66
# 2               10010202001                    233.55
# 3               10010202002                    238.55
# 4               10010203001                    247.96
# ...                     ...                       ...
# 3430            11339658004                    238.57
# 3431            11339658005                    240.85
# 3432            11339659001                    234.09
# 3433            11339659002                    242.73
# 3434            11339659003                    244.07
#
# [3435 rows x 2 columns]

# %%
from striprtf.striprtf import rtf_to_text

def extract_addresses_from_rtfs(folder_path):
    addresses = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".rtf"):
            rtf_path = os.path.join(folder_path, filename)
            with open(rtf_path) as infile:
                content = infile.read()
                text = rtf_to_text(content)
                pattern = r"(?<=\|)\s*([^|]+)\s*\|"
                addresses_dirty = re.findall(pattern, text)
                pattern1 = r".*?\d{5}-\d{4}"
                addresses_clean = [re.findall(pattern1, address) for address in addresses_dirty]
                addresses.append(addresses_clean)
    return addresses

addresses = extract_addresses_from_rtfs("../data/CHC_data")
a1 = [x for x in addresses[0] if x]
a2 = [x for x in addresses[1] if x]
a3 = [x for x in addresses[2] if x]
a4 = [x for x in addresses[3] if x]

addresses_al = a1 + a2 + a3 + a4

addresses_al
    
len(addresses_al) # it's close... allegedly there are 187 CHCs...
# Out:
# [['102 Physicians Dr STE B Muscle Shoals, AL 35661-2149'],
#  ['216 Marengo St STE A Florence, AL 35630-6034'],
#  ['318 Coffee Ave NE Russellville, AL 35653-2331'],
#  ['1841 Al Highway 20 Town Creek, AL 35672-2500'],
#  ['3840 Gault Ave N Fort Payne, AL 35967-5211'],
#  ['34617 Al Highway 75 Fyffe, AL 35971-3488'],
#  ['502 N 27th St Gadsden, AL 35904-1580'],
#  ['2016 Main Ave SW Cullman, AL 35055-5239'],
#  ['12062 Al Highway 227 Geraldine, AL 35974-3562'],
#  ['8225 AL Highway 75 Horton, AL 35980-8473'],
#  ['1216 Wilbanks Ave Gadsden, AL 35903-2024'],
#  ['1409 Springfield Ave Gadsden, AL 35903-2819'],
#  ['420 N 6th St Gadsden, AL 35901-3244'],
#  ['1411 Piedmont Cutoff Gadsden, AL 35903-2708'],
#  ['1411 Piedmont Cutoff Gadsden, AL 35903-2708'],
#  ['1411 Piedmont Cutoff Gadsden, AL 35903-2708'],
#  ['1020 Tuscaloosa Ave Gadsden, AL 35901-3005'],
#  ['1989 Sardis Dr Boaz, AL 35956-2344'],
#  ['25734 Highway 195 Double Springs, AL 35553-2308'],
#  ['156 3rd Ave Nauvoo, AL 35578-3238'],
#  ['1351 Summitt Jasper, AL 35501-0114'],
#  ['1400 19th St W Jasper, AL 35501-5171'],
#  ['5947 Highway 269 Parrish, AL 35580-3847'],
#  ['1501 Viking Dr Jasper, AL 35501-4942'],
#  ['301 Governors Dr SW STE 160 Huntsville, AL 35801-5123'],
#  ['3007 Memorial Pkwy SW STE C Huntsville, AL 35801-5394'],
#  ['4810 Whitesport Cir SW STE 100 Huntsville, AL 35801-7420'],
#  ['4825 University Sq Huntsville, AL 35816-1826'],
#  ['167 Westchester Dr UNIT 1002 Madison, AL 35758-7100'],
#  ['1005 W Market St STE B Athens, AL 35611-2454'],
#  ['751 Pleasant Row NW Huntsville, AL 35816-2537'],
#  ['110 Clinic St New Market, AL 35761-8507'],
#  ['8208 Highway 53 Toney, AL 35773-8582'],
#  ['16410 Highway 72 Rogersville, AL 35652-8117'],
#  ['1304 13th Ave SE STE A Decatur, AL 35601-4316'],
#  ['60 Main St N Section, AL 35771-7168'],
#  ['29810 AL Highway 71 Bryant, AL 35958-5240'],
#  ['70 Freedom Ln Scottsboro, AL 35769-3763'],
#  ['60 Main St N Section, AL 35771-7168'],
#  ['21680 AL Highway 79 Scottsboro, AL 35768-5904'],
#  ['13624 County Road 8 Woodville, AL 35776-6162'],
#  ['813 Franklin St SE Huntsville, AL 35801-4311'],
#  ['2597 Sparkman Dr NW Huntsville, AL 35810-3868'],
#  ['807 Franklin St SE Huntsville, AL 35801-4311'],
#  ['7001 Crestwood Blvd STE 822 Irondale, AL 35210-2344'],
#  ['950 Springville Rd Birmingham, AL 35215-7506'],
#  ['195 Hospital Dr Centreville, AL 35042-2935'],
#  ['1010 1st St N STE 350 Alabaster, AL 35007-8619'],
#  ['160 4th St Brent, AL 35034-3739'],
#  ['260 Walnut St Centreville, AL 35042-2332'],
#  ['405 Belcher St Centreville, AL 35042-2946'],
#  ['9431 Al-22 Maplesville, AL 36750-3264'],
#  ['319 Magnolia St West Blocton, AL 35184-2378'],
#  ['28921 Highway 5 Woodstock, AL 35188-3613'],
#  ['1984 Main St Brent, AL 35034-3503'],
#  ['2152 Old Springville Rd Birmingham, AL 35215-4005'],
#  ['33 Salem Rd STE 2 Montevallo, AL 35115-3586'],
#  ['1000 Lincoln Ave Oneonta, AL 35121-2537'],
#  ['3900 24th St N Birmingham, AL 35207-2614'],
#  ['1220 67th Street Ensley Birmingham, AL 35228-1430'],
#  ['2817 30th Ave N Birmingham, AL 35207-4541'],
#  ['2800 Wilson Rd SW Birmingham, AL 35221-1303'],
#  ['4811 Court J Birmingham, AL 35208-1720'],
#  ['417 19th Street Ensley Birmingham, AL 35218-1601'],
#  ['505 43rd St N Birmingham, AL 35222-1417'],
#  ['712 25th St N Birmingham, AL 35203-2400'],
#  ['712 25th St N Birmingham, AL 35203-2400'],
#  ['1333 19th St N Birmingham, AL 35234-2512'],
#  ['115 4th Ave S Birmingham, AL 35205-3023'],
#  ['2201 Arlington Ave Bessemer, AL 35020-4299'],
#  ['2201 Arlington Ave Bessemer, AL 35020-4299'],
#  ['975 9th Ave SW, Ste 310 Bessemer, AL 35022-7839'],
#  ['623 8th Ave W Birmingham, AL 35204-3604'],
#  ['321 Whiskey Run Rd Camden, AL 36726-2303'],
#  ['715 Valley Rd Fairfield, AL 35064-2666'],
#  ['1925 Avenue E Birmingham, AL 35218-1619'],
#  ['6900 Grasselli Rd Fairfield, AL 35064-2423'],
#  ['1301 Highland Dr Fairfield, AL 35064-1643'],
#  ['714 12th St SW Birmingham, AL 35211-1982'],
#  ['1303 Washington St Marion, AL 36756-3217'],
#  ['801 Princeton Ave SW, Ste 505 Birmingham, AL 35211-1308'],
#  ['301 61st St Fairfield, AL 35064-1900'],
#  ['1308 Tuscaloosa Ave SW Birmingham, AL 35211-1948'],
#  ['5720 1st Ave S Birmingham, AL 35212-2522'],
#  ['5720 1st Ave S Birmingham, AL 35212-2522'],
#  ['5804 1st Ave S Birmingham, AL 35212-2524'],
#  ['140 Front St STE 4 Gilbertown, AL 36908-5510'],
#  ['3550 S Court St Montgomery, AL 36105-2102'],
#  ['511 E Tuskeena St Hayneville, AL 36040-2666'],
#  ['3058 Mobile Hwy Montgomery, AL 36108-4027'],
#  ['3058 Mobile Hwy Montgomery, AL 36108-4027'],
#  ['1845 Cherry St Montgomery, AL 36107-2613'],
#  ['1845 Cherry St Montgomery, AL 36107-2613'],
#  ['228 Selma Ave Selma, AL 36701-5825'],
#  ['1502 US Highway 80 E Demopolis, AL 36732-2200'],
#  ['1310 Washington St Marion, AL 36756-3218'],
#  ['867 County Road 59 Pine Apple, AL 36768-3525'],
#  ['101 Park Pl Selma, AL 36701-6764'],
#  ['111 Main St Thomaston, AL 36783-3137'],
#  ['411 Wilson Ave W Thomasville, AL 36784-2015'],
#  ['330 Old Hamburg Rd Uniontown, AL 36786-2614'],
#  ['2210 Highway 221 Camden, AL 36726-4233'],
#  ['417 3rd St SE Aliceville, AL 35442-2799'],
#  ['800 Hall St Greensboro, AL 36744-2517'],
#  ['2731 Ml King Jr Blvd Tuscaloosa, AL 35401-5235'],
#  ['2731 Ml King Jr Blvd Tuscaloosa, AL 35401-5235'],
#  ['27340 Highway 86 Gordo, AL 35466-3578'],
#  ['415 Derby Dr York, AL 36925-2117'],
#  ['2731 Ml King Jr Blvd Tuscaloosa, AL 35401-5235'],
#  ['200 Morrow Ave Eutaw, AL 35462-1106'],
#  ['376 Commerce Ave Carrollton, AL 35447-2253'],
#  ['24B Camden Byp Camden, AL 36726-1770'],
#  ['127 Clark St Ste C Grove Hill, AL 36451-3050'],
#  ['31431 AL Highway 10 Sweet Water, AL 36782-4941'],
#  ['308 Highway 62 W Ash Flat, AR 72513-9415'],
#  ['1300 Creason Rd Corning, AR 72422-1716'],
#  ['1300 Creason Rd Corning, AR 72422-1716'],
#  ['141 Betty Dr Pocahontas, AR 72455-3602'],
#  ['201 Colonial Dr Walnut Ridge, AR 72476-1410'],
#  ['54 Tate Springs Rd Melbourne, AR 72556-8633'],
#  ['908 N Edmonds Ave McCrory, AR 72101-8073'],
#  ['2624 Highway 42 Cherry Valley, AR 72324-8674'],
#  ['800 Main St Augusta, AR 72006-2449'],
#  ['2450 Batesville Blvd Southside, AR 72501-7782'],
#  ['1310 N Center St Lonoke, AR 72086-2011'],
#  ['416 E Washington Ave Jonesboro, AR 72401-3136'],
#  ['615 N Main St Brinkley, AR 72021-2507'],
#  ['502 Richie Rd Cabot, AR 72023-3309'],
#  ['2000 Harrison St STE D Batesville, AR 72501-7444'],
#  ['1301 Highway 62 E Mountain Home, AR 72653-2708'],
#  ['5510 Southwest Dr STE 12 Jonesboro, AR 72404-8353'],
#  ['821 E Park St # 70 Carlisle, AR 72024-9024'],
#  ['227 Pine Bluff Hwy England, AR 72046-2234'],
#  ['125 Oak St Cotton Plant, AR 72036-5089'],
#  ['2816 Fox Meadow Ln Jonesboro, AR 72404-9346'],
#  ['5787 Highway 64 Parkin, AR 72373-9003'],
#  ['800 Main St Augusta, AR 72006-2449'],
#  ['1503 Main St Des Arc, AR 72040-3299'],
#  ['1175 Vine St Batesville, AR 72501-3526'],
#  ['705 Highway 63 N Hazen, AR 72064-8054'],
#  ['114 Ray St Newport, AR 72112-4260'],
#  ['5830 Highway 5 Cabot, AR 72023-7328'],
#  ['4100 Harrison St Batesville, AR 72501-9419'],
#  ['801 N Edmonds Ave McCrory, AR 72101-8279'],
#  ['1530 N Church St Jonesboro, AR 72401-1515'],
#  ['601 Julia Ave E Wynne, AR 72396-3506'],
#  ['318 S Rhodes St West Memphis, AR 72301-4215'],
#  ['300 Main St Swifton, AR 72471-8809'],
#  ['105 N Jackson St Cabot, AR 72023-3058'],
#  ['322 Dogwood Hollow Rd Mountain View, AR 72560-8626'],
#  ['444 Hospital Dr Mountain Home, AR 72653-2900'],
#  ['1002 N Spring St Harrison, AR 72601-2918'],
#  ['358 Valley St Yellville, AR 72687-9087'],
#  ['2000 W Broadway St Trlr I West Memphis, AR 72301-3829'],
#  ['216 Arkansas St Earle, AR 72331-2217'],
#  ['1008 W Main St Marvell, AR 72366-9486'],
#  ['900 N 7th St West Memphis, AR 72301-2001'],
#  ['102 W Broad St Lepanto, AR 72354-2200'],
#  ['605 N 2nd St Blytheville, AR 72315-2034'],
#  ['513 Porter St Helena, AR 72342-3217'],
#  ['1 Patriot Dr Marion, AR 72364-2408'],
#  ['417 W Main St Trumann, AR 72472-3116'],
#  ['503 S Broadway St Hughes, AR 72348-9724'],
#  ['530 Atkins Blvd Marianna, AR 72360-2198'],
#  ['509 Jackson St Madison, AR 72359-7000'],
#  ['530 Atkins Blvd Marianna, AR 72360-2198'],
#  ['300 S School St Dermott, AR 71638-2127'],
#  ['525 E Speedway St Dermott, AR 71638-2322'],
#  ['579 E Beouff St Eudora, AR 71640-3090'],
#  ['566 S Mabry St Eudora, AR 71640-2941'],
#  ['310 Ashley St Star City, AR 71667-4814'],
#  ['360 W Highway 82 Lake Village, AR 71653-7501'],
#  ['110 N Drew St Star City, AR 71667-5704'],
#  ['557 Kirkwood Rd Star City, AR 71667-8843'],
#  ['206 Cleveland St Star City, AR 71667-5218'],
#  ['245 Madison St Clarendon, AR 72029-2706'],
#  ['2022 S Buerkle St Stuttgart, AR 72160-6508'],
#  ['1940 S Whitehead Dr Dewitt, AR 72042-2906'],
#  ['245 Madison St Clarendon, AR 72029-2706'],
#  ['1400 Braden St STE 1 Jacksonville, AR 72076-3721'],
#  ['630 W South St Benton, AR 72015-4258'],
#  ['138 School Rd Rose Bud, AR 72137-9339'],
#  ['178 Highway 167 N Bald Knob, AR 72010-4058'],
#  ['304 Main St Pangburn, AR 72121-8959'],
#  ['305 Rodgers Dr Searcy, AR 72143-7432'],
#  ['1127 Main St Vilonia, AR 72173-9525'],
#  ['3901 Mccain Park Dr STE 102 North Little Rock, AR 72116-7849'],
#  ['500 S University Ave STE 316 Little Rock, AR 72205-5342'],
#  ['1301 W Center St Beebe, AR 72012-3105'],
#  ['501 Millwood Cir STE E Maumelle, AR 72113-6304'],
#  ['8 N Railroad Ave Mayflower, AR 72106-9430'],
#  ['406 Rodgers Dr Searcy, AR 72143-7433'],
#  ['606 W Wilbur Mills Ave Kensett, AR 72082-9051'],
#  ['1511 Highway 25B Heber Springs, AR 72543-1701'],
#  ['8924 Kanis Rd Little Rock, AR 72205-6414'],
#  ['1500 Museum Rd Conway, AR 72032-4785'],
#  ['465 Medical Center Pkwy Clinton, AR 72031-7946'],
#  ['1094 Catholic Point Rd Center Ridge, AR 72027-8403'],
#  ['326 Southside Rd Bee Branch, AR 72013-9137'],
#  ['2700 N Prickett Rd Ste 1C Bryant, AR 72022-7511'],
#  ['1100 N University Ave STE 260 Little Rock, AR 72207-6367'],
#  ['1100 N University Ave STE 200 Little Rock, AR 72207-6360'],
#  ['1701 S Harrison St Little Rock, AR 72204-2752'],
#  ['4206 Frazier Pike Little Rock, AR 72206-9635'],
#  ['3000 Springer Blvd STE B Little Rock, AR 72206-3314'],
#  ['1100 N University Ave STE 125 Little Rock, AR 72207-6356'],
#  ['2525 Willow St STE 1 North Little Rock, AR 72114-2213'],
#  ['5205 W Sawmill Rd Little Rock, AR 72206-9063'],
#  ['11720 Sr 27 Hector, AR 72843-8712'],
#  ['125 Wellness Way STE 250 Hot Springs, AR 71913-6478'],
#  ['11520 Sr 27 Hector, AR 72843-8710'],
#  ['1903 W Clark Rd Clarksville, AR 72830-3919'],
#  ['401 East St Texarkana, AR 71854-6507'],
#  ['7300 Dollarway Rd STE 116 White Hall, AR 71602-3023'],
#  ['Hc 31 Box 310 Deer, AR 72628-9616'],
#  ['210 N Main St Amity, AR 71921-9733'],
#  ['150 N School St Bearden, AR 71720-9594'],
#  ['402 N Lee St Hampton, AR 71744-8937'],
#  ['601 Martin Luther King Ave Ste A El Dorado, AR 71730-6449'],
#  ['820 S Main St Hope, AR 71801-6523'],
#  ['200 E 18th St Hope, AR 71801-8203'],
#  ['1117 Chestnut St Lewisville, AR 71845-8513'],
#  ['1205 E 35th St Texarkana, AR 71854-2746'],
#  ['4077 Jefferson Ave Texarkana, AR 71854-1509'],
#  ['301 Professional Park Dr STE B Arkadelphia, AR 71923-5317'],
#  ['136 Health Park Dr Mena, AR 71953-9072'],
#  ['136 Health Park Dr Mena, AR 71953-9072'],
#  ['1206 W Collin Raye Dr De Queen, AR 71832-2030'],
#  ['4585 N Highway 7 STE 11 Hot Springs Village, AR 71909-8202'],
#  ['900 Martin Luther King Blvd STE 200 Malvern, AR 72104-2217'],
#  ['208 Mcauley Ct STE B Hot Springs, AR 71913-6344'],
#  ['3312 W Main St Russellville, AR 72801-2304'],
#  ['136 Health Park Dr Mena, AR 71953-9072'],
#  ['1 College Cir Malvern, AR 72104-3520'],
#  ['1723 Malvern Ave Hot Springs National Park, AR 71901-7133'],
#  ['1201 Mena St Mena, AR 71953-4280'],
#  ['1517 S Main St Malvern, AR 72104-5231'],
#  ['534 Luzerne St Mount Ida, AR 71957-9449'],
#  ['430 Ballpark Rd Mount Ida, AR 71957-8013'],
#  ['338 Whittington St Mount Ida, AR 71957-9445'],
#  ['139 School Ln Mena, AR 71953-8432'],
#  ['309 S Edline Altheimer, AR 72004-8559'],
#  ['1101 S Tennessee St Pine Bluff, AR 71601-5801'],
#  ['823 River Rd Redfield, AR 72132-9667'],
#  ['212 Scoby Dr Warren, AR 71671-2050'],
#  ['250 University Dr Monticello, AR 71655-8891'],
#  ['1119 S Main St Hamburg, AR 71646-8983'],
#  ['233 N Main St Portland, AR 71663-9230'],
#  ['1012 E Church St STE B Warren, AR 71671-3530'],
#  ['535 Jordan Dr Monticello, AR 71655-5714'],
#  ['206 N Barlett St Hamburg, AR 71646-3342'],
#  ['314 Highway 160 E Portland, AR 71663-9262'],
#  ['506 Little Creek Cut Off Rd Sheridan, AR 72150-7798'],
#  ['512 W Church St STE A Sheridan, AR 72150-2016'],
#  ['208 E Church St Warren, AR 71671-3412'],
#  ['408 N Bradley St Warren, AR 71671-2208'],
#  ['800 N Walnut St Warren, AR 71671-2009'],
#  ['210 Scoby Dr Warren, AR 71671-2050'],
#  ['203 Mccombs St Wilmot, AR 71676-8800'],
#  ['920 S Highway 45 Bonanza, AR 72916-3420'],
#  ['106 N Hill St Clarksville, AR 72830-2961'],
#  ['708 W Main St Clarksville, AR 72830-3411'],
#  ['635 Childers Ave Lamar, AR 72846-8161'],
#  ['9755 W State Highway 22 Ratcliff, AR 72951-9000'],
#  ['2074 Rice St Waldron, AR 72958-7435'],
#  ['300 E 6th St Texarkana, AR 71854-5207'],
#  ['3150 E Heritage Pkwy Farmington, AR 72730-5529'],
#  ['145 N Curtis Ave Pea Ridge, AR 72751-3407'],
#  ['3057 Springdale Ave Springdale, AR 72762-4346'],
#  ['2805 Mid Cities Dr STE 1 Bentonville, AR 72712-4291'],
#  ['1103 W Main St Green Forest, AR 72638-2311'],
#  ['934 N Gaskill St Huntsville, AR 72740-8903'],
#  ['932 N Gaskill St Huntsville, AR 72740-8903'],
#  ['4003 Massard Rd Fort Smith, AR 72903-6221'],
#  ['603 S Division St Lavaca, AR 72941-4129'],
#  ['442 N Main St Mulberry, AR 72947-8574'],
#  ['3202 N 6th St Fort Smith, AR 72904-4164'],
#  ['4900 Kelley Highway Fort Smith, AR 72904-5000'],
#  ['437 N Main St Mulberry, AR 72947-8574'],
#  ['300 E Centerton Blvd STE 12 Centerton, AR 72719-9217'],
#  ['2667 Hylton Rd Springdale, AR 72764-6778'],
#  ['376 N Center St Elkins, AR 72727-3001'],
#  ['3162 W Martin Luther King Blvd # 13AND14 Fayetteville, AR 72704-7679'],
#  ['1923 W Pickens Rd Pea Ridge, AR 72751-2504'],
#  ['3710 W Southern Hills Blvd Rogers, AR 72758-8041'],
#  ['500 S Mount Olive St STE 200 Siloam Springs, AR 72761-3602'],
#  ['610 E Emma Ave STE A Springdale, AR 72764-4685'],
#  ['614 E Emma Ave Springdale, AR 72764-4400'],
#  ['610 E Emma Ave Springdale, AR 72764-4685'],
#  ['420 N West End St STE B Springdale, AR 72764-3002'],
#  ['2878 Powell St Springdale, AR 72764-7333'],
#  ['900 Powell St Springdale, AR 72764-5645'],
#  ['375 N Rupple Rd Fayetteville, AR 72704-6110'],
#  ['2326 Cardinal Dr Springdale, AR 72764-5735'],
#  ['801 Viney Grove Rd Prairie Grove, AR 72753-2623'],
#  ['5517 N 17th Ave Phoenix, AZ 85015-2516'],
#  ['11130 E Cholla St Scottsdale, AZ 85259-3922'],
#  ['9015 N 3rd St Phoenix, AZ 85020-2444'],
#  ['7301 E 2nd St STE 300 Scottsdale, AZ 85251-5627'],
#  ['4131 N 24th St, Ste B102 Phoenix, AZ 85016-6231'],
#  ['16251 N Cave Creek Rd Phoenix, AZ 85032-2976'],
#  ['4909 E McDowell Rd Phoenix, AZ 85008-4227'],
#  ['4117 N 17th St Phoenix, AZ 85016-5921'],
#  ['5860 S Hospital Dr STE 102 Globe, AZ 85501-9449'],
#  ['467 Vista Ave Page, AZ 86040-1478'],
#  ['827 Vista Ave Page, AZ 86040-7501'],
#  ['440 N Navajo Dr Page, AZ 86040-0950'],
#  ['450 W Adamsville Rd Florence, AZ 85132-8582'],
#  ['2920 N 4th St Flagstaff, AZ 86004-1816'],
#  ['2109 Navajo Blvd Holbrook, AZ 86025-1822'],
#  ['2650 E Show Low Lake Rd Show Low, AZ 85901-7955'],
#  ['488 S Mountain Ave Springerville, AZ 85938-5103'],
#  ['1120 W University Ave, Ste 101 Flagstaff, AZ 86001-2851'],
#  ['620 Lee St Winslow, AZ 86047-2435'],
#  ['1501 S Yale St, Ste 252 Flagstaff, AZ 86001-7336'],
#  ['126 E Main St STE B Payson, AZ 85541-5488'],
#  ['300 S 6th St Williams, AZ 86046-0110'],
#  ['1501 S Yale St, Ste 252 Flagstaff, AZ 86001-7336'],
#  ['1 Clinic Rd Grand Canyon, AZ 86023-0290'],
#  ['1284 N Arizona Blvd Coolidge, AZ 85128-3206'],
#  ['174 W Highway 287 Florence, AZ 85132-8170'],
#  ['44572 W Bowlin Rd Maricopa, AZ 85138-4558'],
#  ['51 S Brian Mickelsen Pkwy Cottonwood, AZ 86326-3610'],
#  ['1090 Commerce Dr Prescott, AZ 86305-3700'],
#  ['3212 N Windsong Dr Prescott Valley, AZ 86314-2255'],
#  ['19251 E Oasis Dr Black Canyon City, AZ 85324-8878'],
#  ['15525 N 83rd Ave, Ste 104 Peoria, AZ 85382-5820'],
#  ['9610 N Metro Pkwy W Phoenix, AZ 85051-1402'],
#  ['2025 W Northern Ave Phoenix, AZ 85021-5157'],
#  ['8088 W Whitney Dr Peoria, AZ 85345-6564'],
#  ['2423 W Dunlap Ave, Ste 140 Phoenix, AZ 85021-5818'],
#  ['11851 N 51st Ave STE B110 Glendale, AZ 85304-2823'],
#  ['20440 N 27th Ave Phoenix, AZ 85027-3240'],
#  ['6153 W Olive Ave Glendale, AZ 85302-4564'],
#  ['100 N Gila Blvd Gila Bend, AZ 85337-1016'],
#  ['410 N Malacate St Ajo, AZ 85321-2254'],
#  ['410 N Malacate St Bldg B Ajo, AZ 85321-2254'],
#  ['815 E 15th St Douglas, AZ 85607-1631'],
#  ['310 Arizona St Bisbee, AZ 85603-1502'],
#  ['1100 N F Ave Douglas, AZ 85607-1919'],
#  ['1100 N F Ave Douglas, AZ 85607-1919'],
#  ['815 E 15th St Douglas, AZ 85607-1631'],
#  ['108 Arizona St Bisbee, AZ 85603-1804'],
#  ['815 E 15th St Douglas, AZ 85607-1631'],
#  ['1151 E 16th St Douglas, AZ 85607-1603'],
#  ['1100 N F Ave Douglas, AZ 85607-1919'],
#  ['815 E 15th St Douglas, AZ 85607-1631'],
#  ['1100 N F Ave Douglas, AZ 85607-1919'],
#  ['101 W Irvington Rd Tucson, AZ 85714-3050'],
#  ['1230 S Cherrybell Stra Tucson, AZ 85713-1907'],
#  ['3950 S Country Club Rd, Ste 130 Tucson, AZ 85714-2203'],
#  ['4550 S Palo Verde Rd Tucson, AZ 85714-1943'],
#  ['340 W Prince Rd Tucson, AZ 85705-6168'],
#  ['320 W Prince Rd Tucson, AZ 85705-3526'],
#  ['225 W Irvington Rd Tucson, AZ 85714-3054'],
#  ['7490 S Camino de Oeste Tucson, AZ 85746-9308'],
#  ['839 W Congress St Tucson, AZ 85745-2819'],
#  ['1500 W Commerce Ct Tucson, AZ 85746-6031'],
#  ['1 W Broadway Blvd Tucson, AZ 85701-3029'],
#  ['434 E University Blvd Tucson, AZ 85705-7851'],
#  ['1230 S Cherrybell Stra Ste D Tucson, AZ 85713-1907'],
#  ['1185 S Redondo Center Dr STE 1 Yuma, AZ 85365-2036'],
#  ['3690 S Park Ave, Ste 805 Tucson, AZ 85713-5042'],
#  ['1670 W Ruthrauff Rd Tucson, AZ 85705-1253'],
#  ['1323 W Prince Rd Tucson, AZ 85705-3114'],
#  ['435 E Glenn St Tucson, AZ 85705-4664'],
#  ['12635 W Rudasill Rd Tucson, AZ 85743-9724'],
#  ['1707 W Saint Marys Rd STE 175 Tucson, AZ 85745-2613'],
#  ['950 E Van Buren St Avondale, AZ 85323-1506'],
#  ['1209 W Target Range Rd Nogales, AZ 85621-2466'],
#  ['1852 N Mastick Way Nogales, AZ 85621-1063'],
#  ['1835 N Mastick Way Nogales, AZ 85621-1064'],
#  ['101 N Taylor Ln Patagonia, AZ 85624-9600'],
#  ['1103 Circulo Mercado Rio Rico, AZ 85648-6248'],
#  ['2239 E Frontage Rd Tubac, AZ 85646-9997'],
#  ['801 N 2nd Ave San Luis, AZ 85336-0676'],
#  ['2060 W 24th St Yuma, AZ 85364-6123'],
#  ['815 N Cesar Chavez St San Luis, AZ 85336-6776'],
#  ['675 S Avenue B Yuma, AZ 85364-2749'],
#  ['675 S Avenue B BLDG B Yuma, AZ 85364-2749'],
#  ['28720 S Nogales Hwy Amado, AZ 85645-9997'],
#  ['17388 W 3rd St Arivaca, AZ 85601-0284'],
#  ['18857 S La Canada Dr Sahuarita, AZ 85629-7990'],
#  ['2875 E Sahuarita Rd Sahuarita, AZ 85629-9434'],
#  ['15921 W Ajo Hwy Tucson, AZ 85735-2032'],
#  ['13060 S Sunland Gin Rd Arizona City, AZ 85123-8448'],
#  ['10A Ward Canyon Rd Clifton, AZ 85533-8233'],
#  ['227 Main St Duncan, AZ 85534-9701'],
#  ['103 Fairgrounds Rd Duncan, AZ 85534-8234'],
#  ['2016 W 16th St Safford, AZ 85546-4026'],
#  ['1615 S 1st Ave Safford, AZ 85546-2103'],
#  ['4755 Campus Dr Sierra Vista, AZ 85635-2449'],
#  ['335 S Ocotillo Ave Benson, AZ 85602-6406'],
#  ['10566 N Highway 191 Elfrida, AZ 85610-9021'],
#  ['115 Calle Portal Sierra Vista, AZ 85635-2950'],
#  ['155 Calle Portal, Ste 300 Sierra Vista, AZ 85635-2900'],
#  ['115 Calle Portal Sierra Vista, AZ 85635-2950'],
#  ['155 Calle Portal, Ste 700 Sierra Vista, AZ 85635-2973'],
#  ['3655 E Grant Rd Tucson, AZ 85716-2933'],
#  ['6950 E Golf Links Rd Tucson, AZ 85730-1017'],
#  ['210 E Cottonwood Ln Casa Grande, AZ 85122-2514'],
#  ['115 W 2nd St Casa Grande, AZ 85122-4406'],
#  ['5224 W Dove Centre Rd Marana, AZ 85658-5063'],
#  ['8181 E Irvington Rd Tucson, AZ 85709-4001'],
#  ['13395 N Marana Main St Marana, AZ 85653-7008'],
#  ['2055 W Hospital Dr, Ste 115 Tucson, AZ 85704-7823'],
#  ['13395 N Marana Main St Marana, AZ 85653-7008'],
#  ['2325 N Wyatt Dr Tucson, AZ 85712-2121'],
#  ['2355 N Wyatt Dr, Ste 101 Tucson, AZ 85712-2120'],
#  ['1856 E Innovation Park Dr Tucson, AZ 85755-1963'],
#  ['16701 N Oracle Rd Tucson, AZ 85739-9102'],
#  ['899 N Wilmot Rd, Ste B Tucson, AZ 85711-1712'],
#  ['1856 E Florence Blvd Casa Grande, AZ 85122-5303'],
#  ['580 N Camino Mercado, Ste 8 Casa Grande, AZ 85122-5757'],
#  ['205 N Stuart Blvd Eloy, AZ 85131-2507'],
#  ['865 N Arizola Rd Casa Grande, AZ 85122-6011'],
#  ['1040 W American Ave Oracle, AZ 85623-6089'],
#  ['23 S McNab Pkwy San Manuel, AZ 85631-1156'],
#  ['865 N Arizola Rd Casa Grande, AZ 85122-6011'],
#  ['1864 E Florence Blvd, Ste 2 Casa Grande, AZ 85122-5504'],
#  ['1864 E Florence Blvd, Ste 1 Casa Grande, AZ 85122-5504'],
#  ['1260 S Campbell Ave, #1 Green Valley, AZ 85614-0504'],
#  ['1260 S Campbell Ave, #1 Green Valley, AZ 85614-0504'],
#  ['1260 S Campbell Ave, Bldg 2 Green Valley, AZ 85614-0502'],
#  ['4475 S I 19 Frontage Rd Green Valley, AZ 85614-6335'],
#  ['670 S Park Centre Ave Green Valley, AZ 85614-2132'],
#  ['13299 E Colossal Cave Rd Vail, AZ 85641-9001'],
#  ['625 N Plaza Dr Apache Junction, AZ 85120-5502'],
#  ['22713 S Ellsworth Rd Bldg A Queen Creek, AZ 85142-7886'],
#  ['2080 W Southern Ave BLDG B10 Apache Junction, AZ 85120-7653'],
#  ['4135 S Power Rd, Ste 108 Mesa, AZ 85212-3625'],
#  ['1705 W Main St Mesa, AZ 85201-6920'],
#  ['811 S Hamilton St Chandler, AZ 85225-6308'],
#  ['950 E Main St Mesa, AZ 85203-8820'],
#  ['1840 E Broadway Rd Tempe, AZ 85282-1614'],
#  ['655 S Dobson Rd, Ste 201 Chandler, AZ 85224-5669'],
#  ['1111 S Stapley Dr Mesa, AZ 85204-5059'],
#  ['334 W 10th Pl Ste 101 Mesa, AZ 85201-3499'],
#  ['5845 E Still Cir, Ste 104 Mesa, AZ 85206-3635'],
#  ['500 W Thomas Rd, Ste 870 Phoenix, AZ 85013-4218'],
#  ['3522 N 3rd Ave Phoenix, AZ 85013-3903'],
#  ['3333 E Van Buren St Phoenix, AZ 85008-6812'],
#  ['220 S 12th Ave Phoenix, AZ 85007-3101'],
#  ['333 W Indian School Rd Phoenix, AZ 85013-3205'],
#  ['210 S 12th Ave Phoenix, AZ 85007-3101'],
#  ['3522 N 3rd Ave Phoenix, AZ 85013-3903'],
#  ['3522 N 3rd Ave Phoenix, AZ 85013-3903'],
#  ['3522 N 3rd Ave Phoenix, AZ 85013-3903'],
#  ['3522 N 3rd Ave Phoenix, AZ 85013-3903'],
#  ['7808 W Thomas Rd Bldg Phoenix, AZ 85033-5481'],
#  ['5825 E Calle Guadalupe Guadalupe, AZ 85283-2664'],
#  ['1101 N Central Ave STE 204 Phoenix, AZ 85004-1844'],
#  ['33 W Tamarisk St Phoenix, AZ 85041-2422'],
#  ['5650 S 35th Ave Phoenix, AZ 85041-3531'],
#  ['2525 E Roosevelt St Phoenix, AZ 85008-4948'],
#  ['303 E Baseline Rd Phoenix, AZ 85042-6530'],
#  ['4222 N 51st Ave Phoenix, AZ 85031-1908'],
#  ['1300 N 48th St Phoenix, AZ 85008-5803'],
#  ['635 E Baseline Rd Phoenix, AZ 85042-6551'],
#  ['3830 E Van Buren St Phoenix, AZ 85008-6920'],
#  ['6601 W Thomas Rd Phoenix, AZ 85033-5700'],
#  ['4041 N Central Ave Phoenix, AZ 85012-3330'],
#  ['3864 N 27th Ave Phoenix, AZ 85017-4703'],
#  ['3807 N 7th St Phoenix, AZ 85014-5005'],
#  ['3807 N 7th St Phoenix, AZ 85014-5005'],
#  ['8410 W Thomas Rd, Ste 116 Phoenix, AZ 85037-3356'],
#  ['3807 N 7th St Phoenix, AZ 85014-5005'],
#  ['502 N 27th Ave Phoenix, AZ 85009-4420'],
#  ['1209 S 1st Ave Phoenix, AZ 85003-2605'],
#  ['1510 S 19th Dr Phoenix, AZ 85009-6540'],
#  ['1625 N 39th Ave Phoenix, AZ 85009-2149'],
#  ['1300 S 10th St Phoenix, AZ 85034-4516'],
#  ['4951 Business Park Blvd Anchorage, AK 99503-7174'],
#  ['General Delivery Beaver, AK 99724-9999'],
#  ['161 Steese Hwy Circle, AK 99733-9800'],
#  ['8 Charles St Delta Junction, AK 99737-0320'],
#  ['113 Main Street Akutan, AK 99553-0113'],
#  ['General Delivery Nelson Lagoon, AK 99571-9999'],
#  ['PO Box 172 Sand Point, AK 99661-0172'],
#  ['1606 23rd Ave Fairbanks, AK 99701-6407'],
#  ['323 Carolyn St Kodiak, AK 99615-6376'],
#  ['3449 E Rezanof Dr Kodiak, AK 99615-6952'],
#  ['2414 Mill Bay Rd Kodiak, AK 99615-6654'],
#  ['3248 Mill Bay Rd Kodiak, AK 99615-7804'],
#  ['1911 E Rezanof Dr Kodiak, AK 99615-6602'],
#  ['110 Main Street Ambler, AK 99786-0110'],
#  ['3261 S Big Lake Rd Wasilla, AK 99623-9663'],
#  ['1363 W Spruce Ave Wasilla, AK 99654-5327'],
#  ['425 E Dahlia Ave, Ste L Palmer, AK 99645-6463'],
#  ['PO Box 189 Unalakleet, AK 99684-0189'],
#  ['PO Box 85058 Brevig Mission, AK 99785-0058'],
#  ['General Delivery Teller, AK 99778-9999'],
#  ['805 Frontage Rd Kenai, AK 99611-9104'],
#  ['395 Main Street Loop Kenai, AK 99611-7727'],
#  ['230 E Marydale Ave Soldotna, AK 99669-7648'],
#  ['880 E End Rd Homer, AK 99603-7201'],
#  ['1 Flight Line Rd Port Alsworth, AK 99653-9801'],
#  ['4330 Elmore Rd Anchorage, AK 99508-5907'],
#  ['225 Front St Juneau, AK 99801-1244'],
#  ['16 Main St Haines, AK 99827-0019'],
#  ['950 E Bogard Rd, Ste 233 Wasilla, AK 99654-7185'],
#  ['950 E Bogard Rd Ste 238 Wasilla, AK 99654-7185'],
#  ['General Delivery Alakanuk, AK 99554-9999'],
#  ['General Delivery Anvik, AK 99558-9999'],
#  ['General Delivery Chefornak, AK 99561-9999'],
#  ['General Delivery Chevak, AK 99563-9999'],
#  ['General Delivery Chuathbaluk, AK 99557-9999'],
#  ['General Delivery Crooked Creek, AK 99575-9999'],
#  ['246 Kwiguk St Emmonak, AK 99581-0010'],
#  ['General Delivery Mekoryuk, AK 99630-9999'],
#  ['General Delivery Shageluk, AK 99665-9999']]
# 511

# %%
# reading text from rtf
# from striprtf.striprtf import rtf_to_text

# with open("./AL_CHC/AL01.rtf") as infile:
#     content = infile.read()
#     text = rtf_to_text(content)
# print(text)

# ## regex 1
# pattern = r"(?<=\|)\s*([^|]+)\s*\|"

# addresses_al1_dirty = re.findall(pattern, text)
# addresses_al1_dirty

# ## when all else fails, regex again
# pattern1 = r".*?\d{5}-\d{4}"

# addresses_al1 = [re.findall(pattern1, address) for address in addresses_al1_dirty]
# addresses_al1

# al1 = pd.DataFrame(addresses_al1)
# al1.head()

# %%
al_locations = gpd.tools.geocode(addresses_al, timeout = 100)
al_locations
# filter to point empty, reverse engineer try to find prob from rtf step
# , "Nominatim", timeout = 5000, user_agent = "jwang.23@dartmouth.edu"
# Out:
#                        geometry  \
# 0    POINT (-87.67905 34.74652)
# 1    POINT (-87.68589 34.79468)
# 2                   POINT EMPTY
# 3    POINT (-87.40553 34.68122)
# 4    POINT (-85.69319 34.47377)
# ..                          ...
# 506                 POINT EMPTY
# 507                 POINT EMPTY
# 508                 POINT EMPTY
# 509                 POINT EMPTY
# 510                 POINT EMPTY
#
#                                                address
# 0    Physicians Drive, 35660, Muscle Shoals, Alabam...
# 1    216, South Marengo Street, 35630, South Mareng...
# 2                                                 None
# 3    Joe Wheeler Highway, 35672, Town Creek, Alabam...
# 4    Gault Avenue, 35967, Fort Payne, Alabama, Unit...
# ..                                                 ...
# 506                                               None
# 507                                               None
# 508                                               None
# 509                                               None
# 510                                               None
#
# [511 rows x 2 columns]

# %%
al = pd.DataFrame(al_locations)
al

# %%
al_locations.to_csv("al_locations1.csv")

# %%
# seems like geopandas doesn't like dataframes? unsure why there are "POINT EMPTY" entries
al_locations = gpd.tools.geocode(addresses_al)
al_locations

# %%
fig, ax = plt.subplots(figsize = (10,10))
us_map = gpd.read_file("./states_21basic/states.shp")
us_map[us_map.STATE_ABBR == "AL"].plot(ax = ax, color='lightgrey')
al_locations.plot(ax = ax)
plt.savefig("al_1.png")

# %%
# find which points live in which census blocks and aggregate
# take map of addresses (2nd) + layer of census blocks (1st)
# spatial neighbors
